# %% [markdown]
# # Lab 1 Introduction to NumPy and Matplotlib

# %%
# !wget -nc -qq -O love_and_peace.jpg "https://www.dropbox.com/scl/fi/dhdl7rh8wc4qd9hxby7yr/love_and_peace.jpg?rlkey=897tkmozj8todanxvgghsgm3e&dl=1"

import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np
# Out:
# 'wget' is not recognized as an internal or external command,
# operable program or batch file.

# %% [markdown]
# # Exercises

# %% [markdown]
# 1. Load the image `love_and_peace.jpg`.  Print the first row of the image.  (Display the numbers, don't `imshow()` it.  By "row", I mean the first row of tuples representing the RGB pixels.)

# %%
image = mpimg.imread('love_and_peace.jpg')

print(image[0])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 image = mpimg.imread('love_and_peace.jpg')
#       3 print(image[0])
#
# File c:\Users\haixi\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\matplotlib\image.py:1587, in imread(fname, format)
#    1580 if isinstance(fname, str) and len(parse.urlparse(fname).scheme) > 1:
#    1581     # Pillow doesn't handle URLs directly.
#    1582     raise ValueError(
#    1583         "Please open the URL for reading and pass the "
#    1584         "result to Pillow, e.g. with "
#    1585         "``np.array(PIL.Image.open(urllib.request.urlopen(url)))``."
#    1586         )
# -> 1587 with img_open(fname) as image:
#    1588     return (_pil_png_to_float_array(image)
#    1589             if isinstance(image, PIL.PngImagePlugin.PngImageFile) else
#    1590             pil_to_array(image))
#
# File c:\Users\haixi\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\PIL\Image.py:3639, in open(fp, mode, formats)
#    3637 if is_path(fp):
#    3638     filename = os.fspath(fp)
# -> 3639     fp = builtins.open(filename, "rb")
#    3640     exclusive_fp = True
#    3641 else:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'love_and_peace.jpg'

# %% [markdown]
# 2. Now `imshow()` the first row of the image.  Why does it appear as a column, rather than a row?  Can you change your code so that it appears as a row of RGB pixels?
#
# *Hint: look at the shape of the array after taking the first row.*

# %%
image = mpimg.imread('love_and_peace.jpg')

plt.imshow(image[0])

# %% [markdown]
# 2. Crop out a 256x256 square patch from the center of the image and show it.  (By "crop out" I mean extract or copy pixels from the image.)

# %%
plt.imshow(image[1222:1478,1222:1478])

# %% [markdown]
# 3. Make a new image where you copy the left half of the image and paste it on the right side (so that the new width is 1.5 times the old width).

# %%
left = image[:,:-1350]
plt.imshow(left)

plt.imshow(np.concatenate((image, left), axis=1))

# %% [markdown]
# 4. Repeat the image nine times in a 3x3 square pattern.  Try to do this using a NumPy function, not using a for loop or list comprehension!
#
# *Hint: see `np.tile`.*

# %%
plt.imshow(np.tile(image, (3,3,1)))

# %% [markdown]
# 5. Reverse the order of the third axis and show the result (this will swap the red and blue color channels).
#
# *Hint: you can reverse an axis with `::-1`*

# %%
plt.imshow(image[::-1])

# %% [markdown]
# 6. Multiply the image by two and show the result.  (I mean multiply the values in the array by two.)  Why does the data type of the image matter here?
#
# *Hint: by "data type" I am referring to the `dtype` of the array.*

# %%
doubled = [[y * 2 for y in x] for x in image]
plt.imshow(doubled)
